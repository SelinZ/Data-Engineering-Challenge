# %%
import pandas as pd

df = pd.read_excel('/Users/selinzobu/Desktop/data-engineer-challenge-crawler/data_loader/example-data.xlsx')

# %%
df.head()
# Out:
#    NO ARRIVAL DATE   HS CODE  \
# 0   1   2024-01-31  20041021
# 1   2   2024-01-31  20041021
# 2   3   2024-01-31  20041000
# 3   4   2024-01-31  20041000
# 4   5   2024-01-31  20041000
#
#                                  HS CODE DESCRIPTION     IMPORTER ADDRESS  \
# 0  Potatoes, prepared or preserved otherwise than...                    .
# 1  Potatoes, prepared or preserved otherwise than...                    .
# 2  PAPAS (PATATAS),PREPARADAS O CONSERVADAS, EXC....                    .
# 3  PAPAS (PATATAS),PREPARADAS O CONSERVADAS, EXC....  Sra. Claudia Naulin
# 4  PAPAS (PATATAS),PREPARADAS O CONSERVADAS, EXC....                    .
#
#   IMPORTER COUNTRY           TEL                       E-MAIL  \
# 0         Botswana             .                            .
# 1         Botswana             .                            .
# 2            Chile             .                            .
# 3            Chile  +56 25571125  gerencia@comercialcastro.cl
# ...

# %%
df
# Out:
#      NO ARRIVAL DATE     HS CODE  \
# 0     1   2024-01-31    20041021
# 1     2   2024-01-31    20041021
# 2     3   2024-01-31    20041000
# 3     4   2024-01-31    20041000
# 4     5   2024-01-31    20041000
# ..   ..          ...         ...
# 103  94   2024-01-31    20041001
# 104  95   2024-01-31    20041099
# 105  96   2024-01-31  2004100000
# 106  97   2024-01-31  2004100000
# 107  98   2024-01-31  2004100000
#
#                                    HS CODE DESCRIPTION  \
# 0    Potatoes, prepared or preserved otherwise than...
# 1    Potatoes, prepared or preserved otherwise than...
# 2    PAPAS (PATATAS),PREPARADAS O CONSERVADAS, EXC....
# 3    PAPAS (PATATAS),PREPARADAS O CONSERVADAS, EXC....
# 4    PAPAS (PATATAS),PREPARADAS O CONSERVADAS, EXC....
# ..                                                 ...
# 103                                   Papas (patatas).
# 104                                              Other
# 105                                           Potatoes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   NO                     108 non-null    int64
#  1   ARRIVAL DATE           108 non-null    datetime64[ns]
#  2   HS CODE                108 non-null    int64
#  3   HS CODE DESCRIPTION    108 non-null    object
#  4   IMPORTER ADDRESS       108 non-null    object
#  5   IMPORTER COUNTRY       108 non-null    object
#  6   TEL                    108 non-null    object
#  7   E-MAIL                 108 non-null    object
#  8   WEB                    91 non-null     object
#  9   EXPORTER ADDRESS       27 non-null     object
#  10  COUNTRY OF ORIGIN      106 non-null    object
#  11  IMPORT VALUE           108 non-null    float64
#  12  CURRENCY               105 non-null    object
#  13  NET WEIGHT             108 non-null    float64
# ...

# %%
df.describe()
# Out:
#                NO       HS CODE  IMPORT VALUE     NET WEIGHT   GROSS WEIGHT  \
# count  108.000000  1.080000e+02  1.080000e+02     108.000000     108.000000
# mean    53.574074  1.202277e+09  4.978001e+05    5564.661852   49265.809722
# std     29.964840  3.802218e+09  3.507281e+06   15451.812912   86111.207835
# min      1.000000  2.004100e+05  0.000000e+00       0.000000       0.000000
# 25%     27.750000  2.004100e+07  1.807740e+03       0.000000     687.500000
# 50%     54.500000  2.004100e+07  7.045140e+03       0.000000   18839.420000
# 75%     81.250000  2.004100e+09  2.957201e+04     662.500000   25208.410000
# max     98.000000  2.004103e+10  2.591183e+07  113342.000000  268667.700000
#
#             QUANTITY  NUMBER OF PACKAGES  MANUFACTORING COMPANY  VOLUME
# count     108.000000          108.000000                    0.0   108.0
# mean     9539.602593          154.574074                    NaN     0.0
# ...

# %%
df.columns
# Out:
# Index(['NO', 'ARRIVAL DATE', 'HS CODE', 'HS CODE DESCRIPTION',
#        'IMPORTER ADDRESS', 'IMPORTER COUNTRY', 'TEL', 'E-MAIL', 'WEB',
#        'EXPORTER ADDRESS', 'COUNTRY OF ORIGIN', 'IMPORT VALUE', 'CURRENCY',
#        'NET WEIGHT', 'NET WEIGHT UNIT', 'GROSS WEIGHT', 'GROSS WEIGHT UNIT',
#        'QUANTITY', 'QUANTITY UNIT', 'PRODUCT DETAILS', 'NUMBER OF PACKAGES',
#        'PACKAGES UNIT', 'PLACE OF DELIVERY', 'MANUFACTORING COMPANY',
#        'VOLUME'],
#       dtype='object')

# %%
initial_count = len(df)
df1 = df.drop_duplicates()
print(f"Removed {initial_count - len(df1)} duplicate rows.") 
print(initial_count, len(df1))
#10 duplicate rows removed.
# Out:
# Removed 10 duplicate rows.
# 108 98

# %%
# Step 3: Drop empty columns (fully NaN)
"""initial_count2 = len(df1)
df2 = df1.dropna(axis=1, how='all')
print(f"Dropped {initial_count2 - len(df1.columns)} empty columns.")
print(initial_count2, len(df2))"""
# Out:
# 'initial_count2 = len(df1)\ndf2 = df1.dropna(axis=1, how=\'all\')\nprint(f"Dropped {initial_count2 - len(df1.columns)} empty columns.")\nprint(initial_count2, len(df2))'

# %%
# Detect all NaN, None, or empty cells
nan_or_empty = df1.isnull() | df1.applymap(lambda x: str(x).strip() == '')
print("Cells that are NaN, None, or empty:")
print(nan_or_empty)
# Out:
# Cells that are NaN, None, or empty:
#        NO  ARRIVAL DATE  HS CODE  HS CODE DESCRIPTION  IMPORTER ADDRESS  \
# 0   False         False    False                False             False
# 1   False         False    False                False             False
# 2   False         False    False                False             False
# 3   False         False    False                False             False
# 4   False         False    False                False             False
# ..    ...           ...      ...                  ...               ...
# 93  False         False    False                False             False
# 94  False         False    False                False             False
# 95  False         False    False                False             False
# 96  False         False    False                False             False
# 97  False         False    False                False             False
#
# ...

# %%
columns_with_issues = nan_or_empty.any(axis=0)
print("\nColumns with NaN, None, or empty cells:")
print(columns_with_issues[columns_with_issues].index)
# Out:
# Columns with NaN, None, or empty cells:
# Index(['WEB', 'EXPORTER ADDRESS', 'COUNTRY OF ORIGIN', 'CURRENCY',
#        'NET WEIGHT UNIT', 'GROSS WEIGHT UNIT', 'QUANTITY UNIT',
#        'PRODUCT DETAILS', 'PACKAGES UNIT', 'PLACE OF DELIVERY'],
#       dtype='object')

# %%
df['EXPORTER ADDRESS'] = df['EXPORTER ADDRESS'].astype(str)
type(df['EXPORTER ADDRESS'][0])
# Out:
# str

# %%
print(df['EXPORTER ADDRESS'])
print(type(df['EXPORTER ADDRESS'][0]))
# Out:
# 0      nan
# 1      nan
# 2      nan
# 3      nan
# 4      nan
#       ...
# 103    nan
# 104    nan
# 105    nan
# 106    nan
# 107    nan
# Name: EXPORTER ADDRESS, Length: 108, dtype: object
# <class 'str'>

# %%
print(df['ARRIVAL DATE'][10])
print(type(df['ARRIVAL DATE'][0]))
# Out:
# 2024-01-31 00:00:00
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
type(df['IMPORT VALUE'][0])
# Out:
# numpy.float64
